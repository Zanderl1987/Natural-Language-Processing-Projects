# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import scipy
from scipy import stats
from scipy.stats import norm
from scipy.stats import spearmanr
import datetime
import time
import matplotlib.cbook as cbook
import seaborn as sns
import math as mth
from math import exp
import sklearn

import bokeh
from bokeh.plotting import *
from collections import OrderedDict
from bokeh.io import output_notebook
from bokeh.models import Toggle, BoxAnnotation, CustomJS, HoverTool

output_notebook()

import plotly
import plotly.graph_objs as go
from plotly.graph_objs import *
import plotly.plotly as py
import plotly.tools as tls
import plotly.offline as offline
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import pytz

sns.set_style("white")

# %matplotlib inline


from IPython.display import display

from IPython.display import HTML

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3721ec7f-53fa-4542-b59b-078841a977f5">Loading BokehJS ...</span>
#     </div>

# %%
df1 = pd.read_excel("C:/Users/zanderl/Documents/Data Science/Active Company Data/Company Screening Report.xls",skiprows=6)

#df2 = pd.read_excel("C:/Users/zanderl/Documents/Data Science/Active Company Data/Company Screening Report (1).xls",sheetname=1)
#df3 = pd.read_excel("C:/Users/zanderl/Documents/Data Science/Active Company Data/Company Screening Report (2).xls",sheetname=1)
#df4 = pd.read_excel("C:/Users/zanderl/Documents/Data Science/Active Company Data/Company Screening Report (3).xls",sheetname=1)

# %%
df1.head(25)
# Out:
#                                           Unnamed: 0       Unnamed: 1  \
# 0                                       Company Name  Exchange:Ticker
# 1              ChipMOS TECHNOLOGIES INC. (TSEC:8150)        TSEC:8150
# 2            Chipotle Mexican Grill, Inc. (NYSE:CMG)         NYSE:CMG
# 3                 Chips&Media, Inc. (KOSDAQ:A094360)   KOSDAQ:A094360
# 4                   Chiron Refineries Ltd (TASE:CHR)         TASE:CHR
# 5                   Chita Kogyo Co., Ltd. (NSE:5993)         NSE:5993
# 6            Chitec Technology Co., Ltd. (GTSM:3430)        GTSM:3430
# 7           Chitradurga Spintex Limited (BSE:521244)       BSE:521244
# 8      ChitrChatr Communications Inc. (OTCPK:CHIC.F)     OTCPK:CHIC.F
# 9          Chiu Ting Machinery Co., Ltd. (TSEC:1539)        TSEC:1539
# 10                      Chiyoda Co., Ltd. (TSE:8185)         TSE:8185
# 11                    Chiyoda Corporation (TSE:6366)         TSE:6366
# ...

# %%
columns_list = list(df1.iloc[6:6])
#df1.iloc[5:6]
